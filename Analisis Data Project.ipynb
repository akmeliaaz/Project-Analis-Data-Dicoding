# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Akmelia Zahara
# - **Email:** akmeliazahara@gmail.com
# - **ID Dicoding:** akmeliazahara

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimanakah perubahan tren dari penyewaan sepada sepanjang tahun dan faktor-faktor apa saja yang mempengaruhi?
# - Bagaimana penyewaan sepeda membentuk sebuah pola musiman dalam pengambilan keputusan efektif terhadap persedian/stock sepeda?

# %% [markdown]
# ## Impor Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df_day = pd.read_csv("//day.csv")
df_day.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-eff911ec1688> in <cell line: 1>()
# ----> 1 df_day = pd.read_csv("/DICODING/day.csv")
#       2 df_day.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Insight**:
# - xxx
# - yyy

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Insight**:
# - xxx
# - yyy

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1
# - Conclusion pertanyaan 2
